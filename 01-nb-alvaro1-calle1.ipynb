# %%
from pystratio.xd.xdsession import XDSession
import pandas as pd

xd = XDSession(sc)

# %%
xd.sql("show tables").show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | default|       breast_cancer|      false|
# | default|      breast_cancer1|      false|
# | default|      breast_cancer2|      false|
# | default|breast_cancer_jav...|      false|
# +--------+--------------------+-----------+

# %%
df = xd.sql("select * from default.breast_cancer1").toPandas()
# Out:
# /usr/local/lib/python3.6/dist-packages/pyarrow/__init__.py:157: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn("pyarrow.open_stream is deprecated, please use "

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        6.981         13.43           43.79      143.5
# 1         B        8.196         16.84           51.71      201.9
# 2         B        8.219         20.70           53.27      203.9
# 3         B        8.598         20.98           54.66      221.8
# 4         B        8.618         11.79           54.34      224.5
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11700           0.07568         0.00000             0.000000
# 1          0.08600           0.05943         0.01588             0.005917
# 2          0.09405           0.13050         0.13210             0.021680
# 3          0.12430           0.08963         0.03000             0.009259
# 4          0.09752           0.05272         0.02061             0.007799
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1930  ...         7.930          19.54            50.41
# 1         0.1769  ...         8.964          21.96            57.26
# 2         0.2222  ...         9.092          29.72            58.08
# 3         0.1828  ...         9.565          27.04            62.06
# 4         0.1683  ...         9.507          15.40            59.90
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       185.2            0.1584             0.1202          0.00000
# 1       242.2            0.1297             0.1357          0.06880
# 2       249.8            0.1630             0.4310          0.53810
# 3       273.9            0.1639             0.1698          0.09001
# 4       274.9            0.1733             0.1239          0.11680
#
#    concave_points_worst  symmetry_worst  fractal_dimension_worst
# 0               0.00000          0.2932                  0.09382
# 1               0.02564          0.3105                  0.07409
# 2               0.07879          0.3322                  0.14860
# 3               0.02778          0.2972                  0.07712
# 4               0.04419          0.3220                  0.09026
#
# [5 rows x 31 columns]

# %%
df.diagnosis.unique()
# Out:
# array(['B', 'M'], dtype=object)

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neural_network import MLPClassifier

# %%
df.drop(columns=['diagnosis'], axis=1)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          6.981         13.43           43.79      143.5          0.11700
# 1          8.196         16.84           51.71      201.9          0.08600
# 2          8.219         20.70           53.27      203.9          0.09405
# 3          8.598         20.98           54.66      221.8          0.12430
# 4          8.618         11.79           54.34      224.5          0.09752
# ..           ...           ...             ...        ...              ...
# 295       21.100         20.52          138.10     1384.0          0.09684
# 296       21.560         22.39          142.00     1479.0          0.11100
# 297       21.610         22.28          144.40     1407.0          0.11670
# 298       23.510         24.27          155.10     1747.0          0.10690
# 299       24.630         21.60          165.50     1841.0          0.10300
#
#      compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0             0.07568         0.00000             0.000000         0.1930
# 1             0.05943         0.01588             0.005917         0.1769
# 2             0.13050         0.13210             0.021680         0.2222
# 3             0.08963         0.03000             0.009259         0.1828
# 4             0.05272         0.02061             0.007799         0.1683
# ..                ...             ...                  ...            ...
# 295           0.11750         0.15720             0.115500         0.1554
# 296           0.11590         0.24390             0.138900         0.1726
# 297           0.20870         0.28100             0.156200         0.2162
# 298           0.12830         0.23080             0.141000         0.1797
# 299           0.21060         0.23100             0.147100         0.1991
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07818  ...         7.930          19.54
# 1                   0.06503  ...         8.964          21.96
# 2                   0.08261  ...         9.092          29.72
# 3                   0.06757  ...         9.565          27.04
# 4                   0.07187  ...         9.507          15.40
# ..                      ...  ...           ...            ...
# 295                 0.05661  ...        25.680          32.07
# 296                 0.05623  ...        25.450          26.40
# 297                 0.06606  ...        26.230          28.74
# 298                 0.05506  ...        30.670          30.73
# 299                 0.06739  ...        29.920          26.93
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0              50.41       185.2            0.1584             0.1202
# 1              57.26       242.2            0.1297             0.1357
# 2              58.08       249.8            0.1630             0.4310
# 3              62.06       273.9            0.1639             0.1698
# 4              59.90       274.9            0.1733             0.1239
# ..               ...         ...               ...                ...
# 295           168.20      2022.0            0.1368             0.3101
# 296           166.10      2027.0            0.1410             0.2113
# 297           172.00      2081.0            0.1502             0.5717
# 298           202.40      2906.0            0.1515             0.2678
# 299           205.70      2642.0            0.1342             0.4188
#
#      concavity_worst  concave_points_worst  symmetry_worst  \
# 0            0.00000               0.00000          0.2932
# 1            0.06880               0.02564          0.3105
# 2            0.53810               0.07879          0.3322
# 3            0.09001               0.02778          0.2972
# 4            0.11680               0.04419          0.3220
# ..               ...                   ...             ...
# 295          0.43990               0.22800          0.2268
# 296          0.41070               0.22160          0.2060
# 297          0.70530               0.24220          0.3828
# 298          0.48190               0.20890          0.2593
# 299          0.46580               0.24750          0.3157
#
#      fractal_dimension_worst
# 0                    0.09382
# 1                    0.07409
# 2                    0.14860
# 3                    0.07712
# 4                    0.09026
# ..                       ...
# 295                  0.07425
# 296                  0.07115
# 297                  0.10070
# 298                  0.07738
# 299                  0.09671
#
# [300 rows x 30 columns]

# %%
y = df["diagnosis"]
X = df.drop(columns=['diagnosis'], axis=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.70)

# %%
model = MLPClassifier(activation='logistic', hidden_layer_sizes=(100, 50))

model.fit(X_train, y_train)
pipeline = Pipeline(steps=[('nn', model)])
scores = cross_val_score(pipeline, X_train, y_train, cv=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
scores
# Out:
# array([1.        , 0.92857143, 0.83333333, 0.95238095, 0.83333333])
